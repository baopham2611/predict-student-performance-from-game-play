# %% [markdown]
# #### Import usefull libraries

# %%
import pandas as pd 
import matplotlib as plot 
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

# %% [markdown]
# ###### HELLO! POLA WELLCOME !!!! #######

# %% [markdown]
# # Data Importation

# %%
# Use pandas tool to read and manipulates data frame
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")
df_train_labels = pd.read_csv("train_labels.csv")

# %%
# Display first 10 rows of train.csv
df_train.head(10)
# Out:
#           session_id  index  elapsed_time      event_name   name  level  page  \
# 0  20090312431273200      0             0  cutscene_click  basic      0   NaN
# 1  20090312431273200      1          1323    person_click  basic      0   NaN
# 2  20090312431273200      2           831    person_click  basic      0   NaN
# 3  20090312431273200      3          1147    person_click  basic      0   NaN
# 4  20090312431273200      4          1863    person_click  basic      0   NaN
# 5  20090312431273200      5          3423    person_click  basic      0   NaN
# 6  20090312431273200      6          5197    person_click  basic      0   NaN
# 7  20090312431273200      7          6180    person_click  basic      0   NaN
# 8  20090312431273200      8          7014    person_click  basic      0   NaN
# 9  20090312431273200      9          7946    person_click  basic      0   NaN
#
#    room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  hover_duration  \
# ...

# %%
# Display first 10 rows of test.csv
df_test.head(10)
# Out:
#           session_id  index  elapsed_time      event_name   name  level  page  \
# 0  20090109393214576      0             0  cutscene_click  basic      0   NaN
# 1  20090109393214576      1          1965    person_click  basic      0   NaN
# 2  20090109393214576      2          3614    person_click  basic      0   NaN
# 3  20090109393214576      3          5330    person_click  basic      0   NaN
# 4  20090109393214576      4          6397    person_click  basic      0   NaN
# 5  20090109393214576      5          8864    person_click  basic      0   NaN
# 6  20090109393214576      6         11697    person_click  basic      0   NaN
# 7  20090109393214576      7         12898    person_click  basic      0   NaN
# 8  20090109393214576      8         13847    person_click  basic      0   NaN
# 9  20090109393214576      9         16847    person_click  basic      0   NaN
#
#    room_coor_x  room_coor_y  screen_coor_x  ...  hover_duration  \
# ...

# %%
# Display first 10 rows of train_labels.csv
df_train_labels.head(10)
# Out:
#              session_id  correct
# 0  20090312431273200_q1        1
# 1  20090312433251036_q1        0
# 2  20090312455206810_q1        1
# 3  20090313091715820_q1        0
# 4  20090313571836404_q1        1
# 5  20090314035813970_q1        1
# 6  20090314121766812_q1        1
# 7  20090314221187252_q1        0
# 8  20090314363702160_q1        1
# 9  20090314441803444_q1        1

# %%
# Describe train.csv
df_train.describe()
# Out:
#          session_id         index  elapsed_time         level           page  \
# count  2.629695e+07  2.629695e+07  2.629695e+07  2.629695e+07  564544.000000
# mean   2.113249e+16  6.445102e+02  4.016694e+06  1.219169e+01       3.166559
# std    5.712953e+14  5.457880e+02  3.127032e+07  6.497789e+00       2.063291
# min    2.009031e+16  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    2.101022e+16  2.880000e+02  4.397000e+05  6.000000e+00       1.000000
# 50%    2.104021e+16  5.950000e+02  1.014801e+06  1.300000e+01       3.000000
# 75%    2.110052e+16  8.960000e+02  1.747040e+06  1.800000e+01       5.000000
# max    2.210022e+16  2.047300e+04  1.988607e+09  2.200000e+01       6.000000
#
#         room_coor_x   room_coor_y  screen_coor_x  screen_coor_y  \
# count  2.422367e+07  2.422367e+07   2.422367e+07   2.422367e+07
# mean  -5.490579e+01 -1.162119e+02   4.584098e+02   3.855860e+02
# std    5.202926e+02  2.184710e+02   2.479389e+02   1.298166e+02
# ...

# %%
# Describe test.csv
df_test.describe()
# Out:
#          session_id        index  elapsed_time        level        page  \
# count  3.728000e+03  3728.000000  3.728000e+03  3728.000000  153.000000
# mean   2.009024e+16   670.427039  2.065026e+06    12.171137    3.405229
# std    9.599042e+10   411.203747  2.079750e+06     6.282262    2.037277
# min    2.009011e+16     0.000000  0.000000e+00     0.000000    0.000000
# 25%    2.009011e+16   320.000000  5.708750e+05     7.000000    2.000000
# 50%    2.009031e+16   642.000000  1.174912e+06    11.000000    4.000000
# 75%    2.009031e+16   983.250000  2.481634e+06    18.000000    5.000000
# max    2.009031e+16  1563.000000  6.524025e+06    22.000000    6.000000
#
#        room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  hover_duration  \
# count  3366.000000  3366.000000    3366.000000    3366.000000      353.000000
# mean    -14.706281  -131.060856     463.707665     394.447415     1415.631728
# std     511.111044   224.031904     243.673841     133.453547     2664.616915
# ...

# %%
# Describe test.csv
df_test.describe()
# Out:
#          session_id        index  elapsed_time        level        page  \
# count  3.728000e+03  3728.000000  3.728000e+03  3728.000000  153.000000
# mean   2.009024e+16   670.427039  2.065026e+06    12.171137    3.405229
# std    9.599042e+10   411.203747  2.079750e+06     6.282262    2.037277
# min    2.009011e+16     0.000000  0.000000e+00     0.000000    0.000000
# 25%    2.009011e+16   320.000000  5.708750e+05     7.000000    2.000000
# 50%    2.009031e+16   642.000000  1.174912e+06    11.000000    4.000000
# 75%    2.009031e+16   983.250000  2.481634e+06    18.000000    5.000000
# max    2.009031e+16  1563.000000  6.524025e+06    22.000000    6.000000
#
#        room_coor_x  room_coor_y  screen_coor_x  screen_coor_y  hover_duration  \
# count  3366.000000  3366.000000    3366.000000    3366.000000      353.000000
# mean    -14.706281  -131.060856     463.707665     394.447415     1415.631728
# std     511.111044   224.031904     243.673841     133.453547     2664.616915
# ...

# %%
# Count rows of each columns in train.csv
df_train.count()
# Out:
# session_id        26296946
# index             26296946
# elapsed_time      26296946
# event_name        26296946
# name              26296946
# level             26296946
# page                564544
# room_coor_x       24223674
# room_coor_y       24223674
# screen_coor_x     24223674
# screen_coor_y     24223674
# hover_duration     2002244
# text               9617139
# fqid              18022531
# room_fqid         26296946
# text_fqid          9617244
# fullscreen        26296946
# hq                26296946
# music             26296946
# level_group       26296946
# dtype: int64

# %%
# Count total of rows of each columns in test.csv
df_test.count()
# Out:
# session_id        3728
# index             3728
# elapsed_time      3728
# event_name        3728
# name              3728
# level             3728
# page               153
# room_coor_x       3366
# room_coor_y       3366
# screen_coor_x     3366
# screen_coor_y     3366
# hover_duration     353
# text              1162
# fqid              2505
# room_fqid         3728
# text_fqid         1162
# fullscreen        3728
# hq                3728
# music             3728
# level_group       3728
# session_level        0
# dtype: int64

# %%
#  Count total of rows of each columns in test.csv
df_train_labels.count()
# Out:
# session_id    424116
# correct       424116
# dtype: int64

# %% [markdown]
# # Data preparation

# %%
# Append test.csv to train.csv for a big data set 
df_all = df_train.append(df_test, ignore_index=True)
# Out:
# C:\Users\baoph\AppData\Local\Temp\ipykernel_21104\990209764.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_all = df_train.append(df_test, ignore_index=True)

# %%
# Get the important values
df_all = df_all[["index","session_id","elapsed_time","name","level","text","level_group"]].copy(deep=True)

# %%
# Display heatmap of missing values
plt.figure(figsize=(10,6))
sn.heatmap(df_all.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# <AxesSubplot:>

# %%
# Count total of missing values in each columns
0f_all.isnull().sum()
# Out:
#   File "C:\Users\baoph\AppData\Local\Temp\ipykernel_21104\2274245879.py", line 2
#     0f_all.isnull().sum()
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Data cleansing

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Feature engineering

# %% [markdown]
# # Feature reprocessing

# %% [markdown]
# # Modelling

# %% [markdown]
# # Hyperparameter tunning
